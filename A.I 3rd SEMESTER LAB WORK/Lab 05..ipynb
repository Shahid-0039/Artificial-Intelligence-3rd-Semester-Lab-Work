# %%
import pandas as pd

# %%
df=pd.read_csv("winequality-white.csv", sep=';')

df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
g1=df.groupby('quality')
mean_alcohol=g1.alcohol.mean()
print(mean_alcohol)
# Out:
# quality
# 3    10.345000
# 4    10.152454
# 5     9.808840
# 6    10.575372
# 7    11.367936
# 8    11.636000
# 9    12.180000
# Name: alcohol, dtype: float64

# %%
g2=df.groupby('pH')
print(g2.quality.mean())
# Out:
# pH
# 2.72    6.000000
# 2.74    6.000000
# 2.77    6.000000
# 2.79    5.000000
# 2.80    5.666667
#           ...
# 3.77    5.000000
# 3.79    5.000000
# 3.80    6.000000
# 3.81    6.000000
# 3.82    7.000000
# Name: quality, Length: 103, dtype: float64

# %%
sorting=df.sort_values('quality', ascending=True)
sorting
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3307            9.4              0.24         0.29             8.5      0.037
# 445             7.1              0.32         0.32            11.0      0.038
# 2050           11.8              0.23         0.38            11.1      0.034
# 3810            6.8              0.26         0.34            15.1      0.060
# 3409            6.2              0.23         0.35             0.7      0.051
# ...             ...               ...          ...             ...        ...
# 774             9.1              0.27         0.45            10.6      0.035
# 827             7.4              0.24         0.36             2.0      0.031
# 876             6.9              0.36         0.34             4.2      0.018
# 820             6.6              0.36         0.29             1.6      0.021
# 1605            7.1              0.26         0.49             2.2      0.032
#
# ...

# %%
Sorting=df.sort_values('alcohol', ascending=False)
Sorting
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3918            6.4             0.350         0.28            1.60      0.037
# 4503            5.8             0.610         0.01            8.40      0.041
# 3904            5.0             0.455         0.18            1.90      0.036
# 3150            5.8             0.390         0.47            7.50      0.027
# 1099            5.8             0.290         0.21            2.60      0.025
# ...             ...               ...          ...             ...        ...
# 3835            6.2             0.310         0.23            3.30      0.052
# 3839            6.2             0.310         0.23            3.30      0.052
# 4020            6.4             0.370         0.12            5.90      0.056
# 3265            4.2             0.215         0.23            5.10      0.041
# 2625            4.5             0.190         0.21            0.95      0.033
#
# ...

# %%
# An Other way like both to gather
Sorting_by_value=df.sort_values(by=['alcohol','quality'], ascending=[False,True])
Sorting_by_value
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3918            6.4             0.350         0.28            1.60      0.037
# 4503            5.8             0.610         0.01            8.40      0.041
# 3150            5.8             0.390         0.47            7.50      0.027
# 1099            5.8             0.290         0.21            2.60      0.025
# 3904            5.0             0.455         0.18            1.90      0.036
# ...             ...               ...          ...             ...        ...
# 4020            6.4             0.370         0.12            5.90      0.056
# 3835            6.2             0.310         0.23            3.30      0.052
# 3839            6.2             0.310         0.23            3.30      0.052
# 3265            4.2             0.215         0.23            5.10      0.041
# 2625            4.5             0.190         0.21            0.95      0.033
#
# ...

# %%
df_Red =pd.read_csv('winequality-red.csv',sep=';')
df_Red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_White=pd.read_csv('winequality-white.csv',sep=';')
df_White
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
concated=df_Red+df_White
print(concated)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              14.4              0.97         0.36            22.6      0.121
# 1              14.1              1.18         0.34             4.2      0.147
# 2              15.9              1.04         0.44             9.2      0.142
# 3              18.4              0.51         0.88            10.4      0.133
# 4              14.6              0.93         0.32            10.4      0.134
# ...             ...               ...          ...             ...        ...
# 4893            NaN               NaN          NaN             NaN        NaN
# 4894            NaN               NaN          NaN             NaN        NaN
# 4895            NaN               NaN          NaN             NaN        NaN
# 4896            NaN               NaN          NaN             NaN        NaN
# 4897            NaN               NaN          NaN             NaN        NaN
#
# ...
